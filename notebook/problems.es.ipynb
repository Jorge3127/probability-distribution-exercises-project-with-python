# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial. Función de masa de probabilidad
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial. Función de distribución acumulativa
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial. Función de dstribución cuantil.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"La probabilidad de que un Binomio(10, 0.2) tome el valor 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"La probabilidad de que un Binomial(10, 0.2) tome un valor menor que 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"¿Qué valor de un binomio (10, 0,2) tiene una probabilidad acumulada de 0,9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Genere 2000 valores aleatorios a partir de una distribución binomial (10, 0,2): {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# La probabilidad de que un Binomio(10, 0.2) tome el valor 2: 0.30198988800000004
# La probabilidad de que un Binomial(10, 0.2) tome un valor menor que 2: 0.6777995263999999
# ¿Qué valor de un binomio (10, 0,2) tiene una probabilidad acumulada de 0,9? 4.0
# Genere 2000 valores aleatorios a partir de una distribución binomial (10, 0,2): [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)


fig, axis = plt.subplots(3, 1, figsize = (10, 6))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# TODO

from scipy.stats import norm

print("                  DISTRIBUCION NORMAL             ")
print(" ")
def dnorm(x, mean=0, sd=1):
    """
    Calcula la densidad de probabilidad puntual de la distribución normal.
    """
    result = norm.pdf(x, loc=mean, scale=sd)
    return result

def pnorm(q, mean=0, sd=1):
    """
    Calcula la probabilidad acumulada de la distribución normal.
    """
    result = norm.cdf(q, loc=mean, scale=sd)
    return result

def qnorm(p, mean=0, sd=1):
    """
    Calcula el cuantil para la distribución normal.
    """
    result = norm.ppf(p, loc=mean, scale=sd)
    return result

def rnorm(n, mean=0, sd=1):
    """
Genera valores aleatorios a partir de la distribución normal.
    """
    result = norm.rvs(loc=mean, scale=sd, size=n)
    return result

print(f"Valor puntual de una Normal(0, 1) en 1: {dnorm(1)}")
print(f"Probabilidad acumulada de una Normal(0, 1) en 1: {pnorm(1)}")
print(f"Cuantil para p=0.9 en una Normal(0, 1): {qnorm(0.9)}")
print(f"Generar 2000 valores aleatorios de una Normal(0, 1): {rnorm(2000)}")

print(" ")
print("                  DISTRIBUCION UNIFORME             ")
print(" ")

from scipy.stats import uniform

# Distribución Uniforme

def dunif(x, min=0, max=1):
    """
    Calcula la densidad de probabilidad puntual de la distribución uniforme.
    """
    result = uniform.pdf(x, loc=min, scale=max-min)
    return result

def punif(q, min=0, max=1):
    """
    Calcula la probabilidad acumulada de la distribución uniforme.
    """
    result = uniform.cdf(q, loc=min, scale=max-min)
    return result

def qunif(p, min=0, max=1):
    """
    Calcula el cuantil para la distribución uniforme.
    """
    result = uniform.ppf(p, loc=min, scale=max-min)
    return result

def runif(n, min=0, max=1):
    """
    Genera valores aleatorios a partir de la distribución uniforme.
    """
    result = uniform.rvs(loc=min, scale=max-min, size=n)
    return result

print(f"Valor puntual de una Uniforme(0, 1) en 0.5: {dunif(0.5)}")
print(f"Probabilidad acumulada de una Uniforme(0, 1) en 0.5: {punif(0.5)}")
print(f"Cuantil para p=0.9 en una Uniforme(0, 1): {qunif(0.9)}")
print(f"Generar 2000 valores aleatorios de una Uniforme(0, 1): {runif(2000)}")

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom, norm, uniform

print(' ')
print('                      GRAFICOS                   ')
print(' ')

fig, axs = plt.subplots(2, 3, figsize=(20, 12))

# Distribución Normal
valor_x_normal = np.linspace(-3, 3, 100)
valor_y_normal = norm.pdf(valor_x_normal, loc=0, scale=1)
y_pnorm = norm.cdf(valor_x_normal, loc=0, scale=1)
r_norm = norm.rvs(loc=0, scale=1, size=1000)

# Gráfico para la densidad de probabilidad (dnorm)
axs[0, 0].plot(valor_x_normal, valor_y_normal, color='blue')
axs[0, 0].set_title('GRAFICO DE LA DENSIDAD DE LA PROBABILIDAD DE LA DISTRIBUCION NORMAL')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('f(x)')

# Gráfico para la función de distribución acumulada (pnorm)
axs[0, 1].plot(valor_x_normal, y_pnorm, color='green')
axs[0, 1].set_title('GRAFICO DE LA FUNCION ACUMULADA DE LA DISTRIBUCION NORMAL')
axs[0, 1].set_xlabel('x')
axs[0, 1].set_ylabel('P(X≤x)')

# Gráfico para la generación de valores aleatorios (rnorm)
axs[0, 2].hist(r_norm, bins=30, density=True, color='purple', alpha=0.6)
axs[0, 2].set_title('GRAFICO DE LA GENERACION DE 2000 VALORES ALEATORIOS DE LA DISTRIBUCION NORNAL')
axs[0, 2].set_xlabel('Valor generado')
axs[0, 2].set_ylabel('Frecuencia relativa')

# Distribución Uniforme
x_unif = np.linspace(0, 1, 100)
y_dunif = uniform.pdf(x_unif, loc=0, scale=1)
y_punif = uniform.cdf(x_unif, loc=0, scale=1)
r_unif = uniform.rvs(loc=0, scale=1, size=1000)

# Gráfico para la densidad de probabilidad (dunif)
axs[1, 0].plot(x_unif, y_dunif, color='blue')
axs[1, 0].set_title('GRAFICO DE LA DENSIDAD DE LA PROBABILIDAD DE LA DISTRIBUCION UNIFORME')
axs[1, 0].set_xlabel('x')
axs[1, 0].set_ylabel('f(x)')

# Gráfico para la función de distribución acumulada (punif)
axs[1, 1].plot(x_unif, y_punif, color='green')
axs[1, 1].set_title('GRAFICO DE LA FUNCION ACUMULADA DE LA DISTRIBUCION UNIFORME')
axs[1, 1].set_xlabel('x')
axs[1, 1].set_ylabel('P(X≤x)')

# Gráfico para la generación de valores aleatorios (runif)
axs[1, 2].hist(r_unif, bins=30, density=True, color='purple', alpha=0.6)
axs[1, 2].set_title('GRAFICO DE LA GENERACION DE 2000 VALORES ALEATORIOS DE LA DISTRIBUCION UNIFORME')
axs[1, 2].set_xlabel('Valor generado')
axs[1, 2].set_ylabel('Frecuencia relativa')

# Ajustar el layout
plt.tight_layout()
plt.show()
# Out:
#                   DISTRIBUCION NORMAL
#
# Valor puntual de una Normal(0, 1) en 1: 0.24197072451914337
# Probabilidad acumulada de una Normal(0, 1) en 1: 0.8413447460685429
# Cuantil para p=0.9 en una Normal(0, 1): 1.2815515655446004
# Generar 2000 valores aleatorios de una Normal(0, 1): [ 0.42243497 -0.46618861 -0.36720393 ...  0.6233423  -0.11657135
#   0.21416894]
#
#                   DISTRIBUCION UNIFORME
#
# Valor puntual de una Uniforme(0, 1) en 0.5: 1.0
# Probabilidad acumulada de una Uniforme(0, 1) en 0.5: 0.5
# Cuantil para p=0.9 en una Uniforme(0, 1): 0.9
# Generar 2000 valores aleatorios de una Uniforme(0, 1): [0.1498943  0.08996728 0.56338374 ... 0.73865265 0.95878664 0.86227173]
#
#                       GRAFICOS
